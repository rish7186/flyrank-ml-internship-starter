# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rish7186/flyrank-ml-internship-starter/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# I chose Ranking/Scoring because the goal is to prioritize which items should be reviewed or acted on first. Instead of making only a yes/no prediction, the model assigns a score so that the highest-priority items can be handled first. This helps users make better decisions when resources or time are limited.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
pass

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# The target is a binary label indicating whether an item belongs to a particular class. This label should come from an observed outcome in the data rather than a manually defined rule, so that the model learns from real historical results instead of simply reproducing human-defined logic.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
pass

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# I will use ROC-AUC as the primary success metric because it measures how well the model distinguishes between the two classes across different thresholds. A value closer to 1.0 indicates better performance, while 0.5 is similar to random guessing. I would consider a ROC-AUC above 0.80 to be a good result.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
pass

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# The unit of analysis is one row of the dataframe, where each row represents a single observation (record) from the dataset. Each row contains the features describing that observation, while the columns represent the variables used for analysis and modeling.

# %%
import pandas as pd

# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Display the first few rows of the dataframe

# Fix: Create a sample DataFrame or load your actual data into 'df'
# For demonstration, creating a sample DataFrame:
data = {'col1': [1, 2, 3, 4, 5], 'col2': ['A', 'B', 'C', 'D', 'E'], 'col3': [10.1, 11.2, 12.3, 13.4, 14.5]}
df = pd.DataFrame(data)

print("Shape:", df.shape)
display(df.head())
# Out:
# Shape: (5, 3)
#    col1 col2  col3
# 0     1    A  10.1
# 1     2    B  11.2
# 2     3    C  12.3
# 3     4    D  13.4
# 4     5    E  14.5

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# Machine learning is more suitable than a fixed rule because the decision depends on multiple features that interact in complex ways. A simple if-statement cannot capture these relationships or adapt to new patterns in the data. An ML model can learn these patterns from historical data and make more accurate and consistent predictions as new data becomes available.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
pass

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
